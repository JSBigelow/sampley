# %% [markdown]
# ## ```sampley``` tests - Stage 2 (Periods, Cells, Segments, Presences, PresenceZones, and Absences)

# %% [markdown]
# ### Setup

# %%
from sampley import *

# %%
import_folder = './import/'
export_folder = './export/'

# %%
u_sightings = DataPoints.from_file(
    filepath=import_folder+'sightings.gpkg',
    crs_working='EPSG:32619',
    datetime_col='datetime',
    tz_import='UTC-05:00'
)
# Out:
# Success: file opened.
# Success: reprojected to CRS "EPSG:32619"
# Success: column "datetime" reformatted to datetimes.
# Success: timezone of column "datetime" set to "UTC-05:00".
# Success: datapoint IDs generated.

# %%
u_trackpoints = DataPoints.from_file(
    filepath=import_folder+'trackpoints.csv',
    x_col='lon',
    y_col='lat',
    crs_import='EPSG:4326',
    crs_working='EPSG:32619',
    section_id_col='section_id'
)
# Out:
# Success: file opened.
# Success: X and Y coordinates parsed.
# Success: reprojected to CRS "EPSG:32619"
# Success: datapoint IDs generated.

# %%
u_trackpoints = DataPoints.from_file(
    filepath=import_folder+'trackpoints.csv',
    geometry_col='geometry',
    crs_import='EPSG:4326',
    crs_working='EPSG:32619',
    section_id_col='section_id'
)
# Out:
# Success: file opened.
# Success: geometries parsed.
# Success: reprojected to CRS "EPSG:32619"
# Success: datapoint IDs generated.

# %%
u_trackpoints = DataPoints.from_file(
    filepath=import_folder+'trackpoints.csv',
    x_col='lon',
    y_col='lat',
    crs_import='EPSG:4326',
    crs_working='EPSG:32619',
    datetime_col='datetime',
    datetime_format='%Y-%m-%d %H:%M:%S',
    tz_import='UTC-05:00',
    tz_working='UTC-06:00',
    datapoint_id_col='datapoint_id',
    section_id_col='section_id'
)
# Out:
# Success: file opened.
# Success: X and Y coordinates parsed.
# Success: reprojected to CRS "EPSG:32619"
# Success: column "datetime" reformatted to datetimes.
# Success: timezone of column "datetime" set to "UTC-05:00".
# Success: column "datetime" converted to timezone "UTC-06:00"

# %%
u_trackpoints.name
# Out:
# 'datapoints-trackpoints'

# %%
u_trackpoints.parameters
# Out:
# {'datapoints_filepath': './import/trackpoints.csv',
#  'datapoints_crs': 'EPSG:32619',
#  'datapoints_tz': 'UTC-06:00',
#  'datapoints_data_cols': 'section_id, individuals, bss, season'}

# %%
u_trackpoints.datapoints
# Out:
#      datapoint_id section_id                        geometry  \
# 0          dp0001       s001  POINT (580092.757 4742883.408)
# 1          dp0002       s001  POINT (579997.135 4742882.297)
# 2          dp0003       s001  POINT (579616.283 4742877.883)
# 3          dp0004       s001   POINT (579166.78 4742872.701)
# 4          dp0005       s001  POINT (578880.732 4742869.419)
# ...           ...        ...                             ...
# 1762       dp1763       s004   POINT (603283.221 4696803.55)
# 1763       dp1764       s004  POINT (602912.975 4696798.087)
# 1764       dp1765       s004   POINT (602582.514 4696885.41)
# 1765       dp1766       s004  POINT (602458.009 4696957.996)
# 1766       dp1767       s004  POINT (602389.184 4696993.638)
#
#                       datetime  individuals  bss  season
# 0    2019-01-25 09:18:13-06:00          NaN    2  winter
# 1    2019-01-25 09:18:15-06:00          NaN    2  winter
# 2    2019-01-25 09:18:23-06:00          NaN    2  winter
# 3    2019-01-25 09:18:32-06:00          1.0    2  winter
# 4    2019-01-25 09:18:38-06:00          NaN    2  winter
# ...                        ...          ...  ...     ...
# 1762 2019-03-05 12:09:25-06:00          NaN    3  spring
# 1763 2019-03-05 12:09:33-06:00          NaN    3  spring
# 1764 2019-03-05 12:09:41-06:00          NaN    3  spring
# 1765 2019-03-05 12:09:45-06:00          NaN    3  spring
# 1766 2019-03-05 12:09:46-06:00          NaN    3  spring
#
# [1767 rows x 7 columns]

# %%
u_trackpoints.save(
    folder=export_folder, 
    crs_export='EPSG:4326', 
    tz_export='UTC-05:00')
# Out:
# Success: reprojected to CRS "EPSG:4326"
# Success: column "datetime" converted to timezone "UTC-05:00"

# %%
u_trackpoints = DataPoints.open(
    export_folder, 
    basename='datapoints-trackpoints', 
    crs_working='EPSG:32619',
    tz_working='UTC-06:00')
# Out:
# Success: file opened.
# Success: file opened.
# Success: reprojected to CRS "EPSG:32619"
# Success: column "datetime" reformatted to datetimes.
# Note: the inherent (contained within the datetimes) timezone of column "datetime" is "UTC-05:00".
# Success: column "datetime" converted to timezone "UTC-06:00"

# %%
u_sections = Sections.from_file(filepath=import_folder+'sections.gpkg', crs_working='EPSG:32619')
u_sightings.plot(sections=u_sections)
# Out:
# Success: file opened.
# Success: reprojected to CRS "EPSG:32619"
# Success: section IDs generated.

# %%
u_sections = Sections.from_file(
    filepath=import_folder+'sections.gpkg',
    crs_working='EPSG:32619'
)
# Out:
# Success: file opened.
# Success: reprojected to CRS "EPSG:32619"
# Success: section IDs generated.

# %%
u_sections = Sections.from_file(
    filepath=import_folder+'sections.gpkg',
    crs_working='EPSG:32619',
    datetime_col='datetime',
    datetime_format='%Y-%m-%d %H:%M:%S',
    tz_import='UTC-05:00',
    tz_working='UTC-06:00',
    section_id_col='section_id'
)
# Out:
# Success: file opened.
# Success: reprojected to CRS "EPSG:32619"
# Success: column "datetime" reformatted to datetimes.
# Success: timezone of column "datetime" set to "UTC-05:00".
# Success: column "datetime" converted to timezone "UTC-06:00"

# %%
u_trackpoints = DataPoints.from_file(
    filepath=import_folder+'trackpoints.csv',
    x_col='lon',
    y_col='lat',
    crs_import='EPSG:4326',
    crs_working='EPSG:32619',
    datetime_col='datetime',
    tz_import='UTC-05:00',
    section_id_col='section_id'
)
u_sections = Sections.from_datapoints(
    datapoints=u_trackpoints,
    cols={'bss': 'mean', 'season': 'first', 'datetime': 'first'},
    sortby='datetime')
# Out:
# Success: file opened.
# Success: X and Y coordinates parsed.
# Success: reprojected to CRS "EPSG:32619"
# Success: column "datetime" reformatted to datetimes.
# Success: timezone of column "datetime" set to "UTC-05:00".
# Success: datapoint IDs generated.

# %%
u_sections.name
# Out:
# 'sections-trackpoints'

# %%
u_sections.parameters
# Out:
# {'sections_filepath': './import/trackpoints.csv (via datapoints)',
#  'sections_crs': 'EPSG:32619',
#  'sections_tz': 'UTC-05:00'}

# %%
u_sections.sections
# Out:
#   section_id                                           geometry  \
# 0       s001  LINESTRING (580092.757 4742883.408, 579997.135...
# 1       s002  LINESTRING (592927.566 4733678.432, 592818.466...
# 2       s003  LINESTRING (500383.195 4714750.316, 500765.569...
# 3       s004  LINESTRING (656499.299 4751214.73, 656509.418 ...
#
#                    datetime       bss  season
# 0 2019-01-25 10:18:13-05:00  2.398058  winter
# 1 2019-01-30 14:32:57-05:00  3.000000  winter
# 2 2019-03-02 12:43:27-05:00  1.537864  spring
# 3 2019-03-05 11:21:16-05:00  1.280872  spring

# %%
u_sections.save(
    folder=export_folder, 
    crs_export='EPSG:4326', 
    tz_export='UTC-05:00')
# Out:
# Success: reprojected to CRS "EPSG:4326"
# Note: conversion of column "datetime" to timezone "UTC-05:00" not necessary as already in timezone "UTC-05:00".

# %%
u_sections = Sections.open(
    export_folder, 
    basename='sections-trackpoints', 
    crs_working='EPSG:32619',
    tz_working='UTC-06:00')
# Out:
# Success: file opened.
# Success: file opened.
# Success: reprojected to CRS "EPSG:32619"
# Success: column "datetime" reformatted to datetimes.
# Note: the inherent (contained within the datetimes) timezone of column "datetime" is "UTC-05:00".
# Success: column "datetime" converted to timezone "UTC-06:00"

# %%
u_sightings = DataPoints.from_file(filepath=import_folder+'sightings.gpkg', crs_working='EPSG:32619')
u_sections.plot(datapoints=u_sightings)
# Out:
# Success: file opened.
# Success: reprojected to CRS "EPSG:32619"
# Success: datapoint IDs generated.

# %% [markdown]
# ### Periods

# %% [markdown]
# #### ```Periods.delimit```

# %% [markdown]
# ##### Custom extent

# %%
u_periods = Periods.delimit(
    extent=(['2019-01-25 10:18:13', '2019-03-03 14:32:57'], 'UTC-05:00'),
    unit='day',
    num=8)
u_periods.periods
# Out:
# Success: column "datetime" reformatted to datetimes.
# Success: timezone of column "datetime" set to "UTC-05:00".
#         period_id                  date_beg                  date_mid  \
# 0  p2019-01-25-8d 2019-01-25 00:00:00-05:00 2019-01-29 00:00:00-05:00
# 1  p2019-02-02-8d 2019-02-02 00:00:00-05:00 2019-02-06 00:00:00-05:00
# 2  p2019-02-10-8d 2019-02-10 00:00:00-05:00 2019-02-14 00:00:00-05:00
# 3  p2019-02-18-8d 2019-02-18 00:00:00-05:00 2019-02-22 00:00:00-05:00
# 4  p2019-02-26-8d 2019-02-26 00:00:00-05:00 2019-03-02 00:00:00-05:00
#
#                    date_end
# 0 2019-02-01 00:00:00-05:00
# 1 2019-02-09 00:00:00-05:00
# 2 2019-02-17 00:00:00-05:00
# 3 2019-02-25 00:00:00-05:00
# 4 2019-03-05 00:00:00-05:00

# %%
u_periods = Periods.delimit(
    extent=(['2019-01-25 10:18:13', '2019-10-03 14:32:57'], 'UTC-05:00'),
    unit='month',
    num=2)
u_periods.periods
# Out:
# Success: column "datetime" reformatted to datetimes.
# Success: timezone of column "datetime" set to "UTC-05:00".
#         period_id                  date_beg                  date_mid  \
# 0  p2019-01-01-2m 2019-01-01 00:00:00-05:00 2019-01-30 00:00:00-05:00
# 1  p2019-03-01-2m 2019-03-01 00:00:00-05:00 2019-03-31 00:00:00-05:00
# 2  p2019-05-01-2m 2019-05-01 00:00:00-05:00 2019-05-31 00:00:00-05:00
# 3  p2019-07-01-2m 2019-07-01 00:00:00-05:00 2019-08-01 00:00:00-05:00
# 4  p2019-09-01-2m 2019-09-01 00:00:00-05:00 2019-10-01 00:00:00-05:00
#
#                    date_end
# 0 2019-02-28 00:00:00-05:00
# 1 2019-04-30 00:00:00-05:00
# 2 2019-06-30 00:00:00-05:00
# 3 2019-08-31 00:00:00-05:00
# 4 2019-10-31 00:00:00-05:00

# %%
u_periods = Periods.delimit(
    extent=(['2019-01-25 10:18:13', '2023-10-03 14:32:57'], 'UTC-05:00'),
    unit='year',
    num=1)
u_periods.periods
# Out:
# Success: column "datetime" reformatted to datetimes.
# Success: timezone of column "datetime" set to "UTC-05:00".
#         period_id                  date_beg                  date_mid  \
# 0  p2019-01-01-1y 2019-01-01 00:00:00-05:00 2019-07-02 00:00:00-05:00
# 1  p2020-01-01-1y 2020-01-01 00:00:00-05:00 2020-07-02 00:00:00-05:00
# 2  p2021-01-01-1y 2021-01-01 00:00:00-05:00 2021-07-02 00:00:00-05:00
# 3  p2022-01-01-1y 2022-01-01 00:00:00-05:00 2022-07-02 00:00:00-05:00
# 4  p2023-01-01-1y 2023-01-01 00:00:00-05:00 2023-07-02 00:00:00-05:00
#
#                    date_end
# 0 2019-12-31 00:00:00-05:00
# 1 2020-12-31 00:00:00-05:00
# 2 2021-12-31 00:00:00-05:00
# 3 2022-12-31 00:00:00-05:00
# 4 2023-12-31 00:00:00-05:00

# %%
u_periods = Periods.delimit(
    extent=(['2019-01-25 10:18:13', '2019-03-03 14:32:57'], None),
    unit='day',
    num=8)
u_periods.periods
# Out:
# Success: column "datetime" reformatted to datetimes.
# Note: timezone of column "datetime" was not set as no timezone was specified.
#         period_id   date_beg   date_mid   date_end
# 0  p2019-01-25-8d 2019-01-25 2019-01-29 2019-02-01
# 1  p2019-02-02-8d 2019-02-02 2019-02-06 2019-02-09
# 2  p2019-02-10-8d 2019-02-10 2019-02-14 2019-02-17
# 3  p2019-02-18-8d 2019-02-18 2019-02-22 2019-02-25
# 4  p2019-02-26-8d 2019-02-26 2019-03-02 2019-03-05

# %%
u_periods = Periods.delimit(
    extent=(['2019-01-25 10:18:13', '2019-10-03 14:32:57'], None),
    unit='month',
    num=2)
u_periods.periods
# Out:
# Success: column "datetime" reformatted to datetimes.
# Note: timezone of column "datetime" was not set as no timezone was specified.
#         period_id   date_beg   date_mid   date_end
# 0  p2019-01-01-2m 2019-01-01 2019-01-30 2019-02-28
# 1  p2019-03-01-2m 2019-03-01 2019-03-31 2019-04-30
# 2  p2019-05-01-2m 2019-05-01 2019-05-31 2019-06-30
# 3  p2019-07-01-2m 2019-07-01 2019-08-01 2019-08-31
# 4  p2019-09-01-2m 2019-09-01 2019-10-01 2019-10-31

# %%
u_periods = Periods.delimit(
    extent=(['2019-01-25 10:18:13', '2023-10-03 14:32:57'], None),
    unit='year',
    num=1)
u_periods.periods
# Out:
# Success: column "datetime" reformatted to datetimes.
# Note: timezone of column "datetime" was not set as no timezone was specified.
#         period_id   date_beg   date_mid   date_end
# 0  p2019-01-01-1y 2019-01-01 2019-07-02 2019-12-31
# 1  p2020-01-01-1y 2020-01-01 2020-07-02 2020-12-31
# 2  p2021-01-01-1y 2021-01-01 2021-07-02 2021-12-31
# 3  p2022-01-01-1y 2022-01-01 2022-07-02 2022-12-31
# 4  p2023-01-01-1y 2023-01-01 2023-07-02 2023-12-31

# %% [markdown]
# ##### Extent based on DataPoints

# %%
u_trackpoints = DataPoints.from_file(
    filepath=import_folder+'trackpoints.csv',
    x_col='lon',
    y_col='lat',
    crs_import='EPSG:4326',
    crs_working='EPSG:32619',
    datetime_col='datetime',
    tz_import='UTC-05:00',
    tz_working='UTC-06:00'
)
u_periods = Periods.delimit(
    extent=u_trackpoints,
    unit='day',
    num=8)
u_periods.periods
# Out:
# Success: file opened.
# Success: X and Y coordinates parsed.
# Success: reprojected to CRS "EPSG:32619"
# Success: column "datetime" reformatted to datetimes.
# Success: timezone of column "datetime" set to "UTC-05:00".
# Success: column "datetime" converted to timezone "UTC-06:00"
# Success: datapoint IDs generated.
#         period_id                  date_beg                  date_mid  \
# 0  p2019-01-25-8d 2019-01-25 00:00:00-06:00 2019-01-29 00:00:00-06:00
# 1  p2019-02-02-8d 2019-02-02 00:00:00-06:00 2019-02-06 00:00:00-06:00
# 2  p2019-02-10-8d 2019-02-10 00:00:00-06:00 2019-02-14 00:00:00-06:00
# 3  p2019-02-18-8d 2019-02-18 00:00:00-06:00 2019-02-22 00:00:00-06:00
# 4  p2019-02-26-8d 2019-02-26 00:00:00-06:00 2019-03-02 00:00:00-06:00
#
#                    date_end
# 0 2019-02-01 00:00:00-06:00
# 1 2019-02-09 00:00:00-06:00
# 2 2019-02-17 00:00:00-06:00
# 3 2019-02-25 00:00:00-06:00
# 4 2019-03-05 00:00:00-06:00

# %% [markdown]
# ##### Extent based on Sections

# %%
u_sections = Sections.from_file(
    filepath=import_folder+'sections.gpkg',
    crs_working='EPSG:32619',
    datetime_col='datetime',
    tz_import='UTC-05:00',
    tz_working='UTC-06:00',
)
u_periods = Periods.delimit(
    extent=u_sections,
    unit='day',
    num=8)
u_periods.periods
# Out:
# Success: file opened.
# Success: reprojected to CRS "EPSG:32619"
# Success: column "datetime" reformatted to datetimes.
# Success: timezone of column "datetime" set to "UTC-05:00".
# Success: column "datetime" converted to timezone "UTC-06:00"
# Success: section IDs generated.
#         period_id                  date_beg                  date_mid  \
# 0  p2019-01-25-8d 2019-01-25 00:00:00-06:00 2019-01-29 00:00:00-06:00
# 1  p2019-02-02-8d 2019-02-02 00:00:00-06:00 2019-02-06 00:00:00-06:00
# 2  p2019-02-10-8d 2019-02-10 00:00:00-06:00 2019-02-14 00:00:00-06:00
# 3  p2019-02-18-8d 2019-02-18 00:00:00-06:00 2019-02-22 00:00:00-06:00
# 4  p2019-02-26-8d 2019-02-26 00:00:00-06:00 2019-03-02 00:00:00-06:00
#
#                    date_end
# 0 2019-02-01 00:00:00-06:00
# 1 2019-02-09 00:00:00-06:00
# 2 2019-02-17 00:00:00-06:00
# 3 2019-02-25 00:00:00-06:00
# 4 2019-03-05 00:00:00-06:00

# %% [markdown]
# #### Periods attributes

# %%
u_periods.name
# Out:
# 'periods-8d'

# %%
u_periods.parameters
# Out:
# {'periods_tz': 'UTC-06:00',
#  'periods_extent': '2019-01-25-2019-03-05',
#  'periods_extent_source': 'Sections - sections-sections',
#  'periods_number': 8,
#  'periods_unit': 'day'}

# %%
u_periods.periods
# Out:
#         period_id                  date_beg                  date_mid  \
# 0  p2019-01-25-8d 2019-01-25 00:00:00-06:00 2019-01-29 00:00:00-06:00
# 1  p2019-02-02-8d 2019-02-02 00:00:00-06:00 2019-02-06 00:00:00-06:00
# 2  p2019-02-10-8d 2019-02-10 00:00:00-06:00 2019-02-14 00:00:00-06:00
# 3  p2019-02-18-8d 2019-02-18 00:00:00-06:00 2019-02-22 00:00:00-06:00
# 4  p2019-02-26-8d 2019-02-26 00:00:00-06:00 2019-03-02 00:00:00-06:00
#
#                    date_end
# 0 2019-02-01 00:00:00-06:00
# 1 2019-02-09 00:00:00-06:00
# 2 2019-02-17 00:00:00-06:00
# 3 2019-02-25 00:00:00-06:00
# 4 2019-03-05 00:00:00-06:00

# %% [markdown]
# #### ```Periods.save```

# %%
u_periods.save(folder=export_folder)

# %% [markdown]
# #### ```Periods.open```

# %%
u_periods = Periods.open(
    export_folder, 
    basename='periods-8d')
# Out:
# Success: file opened.
# Success: file opened.

# %% [markdown]
# ### Cells

# %% [markdown]
# #### ```Cells.delimit```

# %% [markdown]
# ##### Custom extent

# %%
from pyproj import CRS
u_cells = Cells.delimit(
    extent=([500095.61955057, 4696798.08683991, 657711.42048071, 4751214.73038492], CRS('EPSG:32619')),
    var='hexagonal',
    side=5000)
u_cells.cells
# Out:
#          cell_id                                            polygon  \
# 0    c001-h5000m  POLYGON ((500095.62 4701798.087, 504425.747 46...
# 1    c002-h5000m  POLYGON ((508755.874 4701798.087, 513086.001 4...
# 2    c003-h5000m  POLYGON ((517416.128 4701798.087, 521746.255 4...
# 3    c004-h5000m  POLYGON ((526076.382 4701798.087, 530406.509 4...
# 4    c005-h5000m  POLYGON ((534736.636 4701798.087, 539066.763 4...
# ..           ...                                                ...
# 175  c176-h5000m  POLYGON ((629999.43 4761798.087, 634329.557 47...
# 176  c177-h5000m  POLYGON ((638659.684 4761798.087, 642989.811 4...
# 177  c178-h5000m  POLYGON ((647319.938 4761798.087, 651650.065 4...
# 178  c179-h5000m  POLYGON ((655980.192 4761798.087, 660310.319 4...
# 179  c180-h5000m  POLYGON ((664640.446 4761798.087, 668970.573 4...
#
#                            centroid
# 0     POINT (500095.62 4696798.087)
# 1    POINT (508755.874 4696798.087)
# 2    POINT (517416.128 4696798.087)
# 3    POINT (526076.382 4696798.087)
# 4    POINT (534736.636 4696798.087)
# ..                              ...
# 175   POINT (629999.43 4756798.087)
# 176  POINT (638659.684 4756798.087)
# 177  POINT (647319.938 4756798.087)
# 178  POINT (655980.192 4756798.087)
# 179  POINT (664640.446 4756798.087)
#
# [180 rows x 3 columns]

# %%
from pyproj import CRS
u_cells = Cells.delimit(
    extent=([500095.61955057, 4696798.08683991, 657711.42048071, 4751214.73038492], CRS('EPSG:32619')),
    var='rectangular',
    side=5000,
    buffer=2000)
u_cells.cells
# Out:
#          cell_id                                            polygon  \
# 0    c001-r5000m  POLYGON ((498095.62 4694798.087, 503095.62 469...
# 1    c002-r5000m  POLYGON ((503095.62 4694798.087, 508095.62 469...
# 2    c003-r5000m  POLYGON ((508095.62 4694798.087, 513095.62 469...
# 3    c004-r5000m  POLYGON ((513095.62 4694798.087, 518095.62 469...
# 4    c005-r5000m  POLYGON ((518095.62 4694798.087, 523095.62 469...
# ..           ...                                                ...
# 391  c392-r5000m  POLYGON ((638095.62 4749798.087, 643095.62 474...
# 392  c393-r5000m  POLYGON ((643095.62 4749798.087, 648095.62 474...
# 393  c394-r5000m  POLYGON ((648095.62 4749798.087, 653095.62 474...
# 394  c395-r5000m  POLYGON ((653095.62 4749798.087, 658095.62 474...
# 395  c396-r5000m  POLYGON ((658095.62 4749798.087, 663095.62 474...
#
#                           centroid
# 0    POINT (500595.62 4697298.087)
# 1    POINT (505595.62 4697298.087)
# 2    POINT (510595.62 4697298.087)
# 3    POINT (515595.62 4697298.087)
# 4    POINT (520595.62 4697298.087)
# ..                             ...
# 391  POINT (640595.62 4752298.087)
# 392  POINT (645595.62 4752298.087)
# 393  POINT (650595.62 4752298.087)
# 394  POINT (655595.62 4752298.087)
# 395  POINT (660595.62 4752298.087)
#
# [396 rows x 3 columns]

# %% [markdown]
# ##### Extent based on polygon

# %%
import geopandas as gpd  # import geopandas package
study_area = gpd.read_file(import_folder + 'study_area.gpkg')  # import the GeoPackage as a GeoDataFrame
u_cells = Cells.delimit(
    extent=study_area,
    var='hexagonal',
    side=5000)
u_cells.cells
# Out:
#          cell_id                                            polygon  \
# 0    c001-h5000m  POLYGON ((500095.62 4701798.087, 504425.747 46...
# 1    c002-h5000m  POLYGON ((508755.874 4701798.087, 513086.001 4...
# 2    c003-h5000m  POLYGON ((517416.128 4701798.087, 521746.255 4...
# 3    c004-h5000m  POLYGON ((526076.382 4701798.087, 530406.509 4...
# 4    c005-h5000m  POLYGON ((534736.636 4701798.087, 539066.763 4...
# ..           ...                                                ...
# 175  c176-h5000m  POLYGON ((629999.43 4761798.087, 634329.557 47...
# 176  c177-h5000m  POLYGON ((638659.684 4761798.087, 642989.811 4...
# 177  c178-h5000m  POLYGON ((647319.938 4761798.087, 651650.065 4...
# 178  c179-h5000m  POLYGON ((655980.192 4761798.087, 660310.319 4...
# 179  c180-h5000m  POLYGON ((664640.446 4761798.087, 668970.573 4...
#
#                            centroid
# 0     POINT (500095.62 4696798.087)
# 1    POINT (508755.874 4696798.087)
# 2    POINT (517416.128 4696798.087)
# 3    POINT (526076.382 4696798.087)
# 4    POINT (534736.636 4696798.087)
# ..                              ...
# 175   POINT (629999.43 4756798.087)
# 176  POINT (638659.684 4756798.087)
# 177  POINT (647319.938 4756798.087)
# 178  POINT (655980.192 4756798.087)
# 179  POINT (664640.446 4756798.087)
#
# [180 rows x 3 columns]

# %% [markdown]
# ##### Extent based on DataPoints

# %%
u_trackpoints = DataPoints.from_file(
    filepath=import_folder+'trackpoints.csv',
    geometry_col='geometry',
    crs_import='EPSG:4326',
    crs_working='EPSG:32619',
    section_id_col='section_id'
)
u_cells = Cells.delimit(
    extent=u_trackpoints,
    var='hexagonal',
    side=5000)
u_cells.cells
# Out:
# Success: file opened.
# Success: geometries parsed.
# Success: reprojected to CRS "EPSG:32619"
# Success: datapoint IDs generated.
#          cell_id                                            polygon  \
# 0    c001-h5000m  POLYGON ((500095.62 4701798.087, 504425.747 46...
# 1    c002-h5000m  POLYGON ((508755.874 4701798.087, 513086.001 4...
# 2    c003-h5000m  POLYGON ((517416.128 4701798.087, 521746.255 4...
# 3    c004-h5000m  POLYGON ((526076.382 4701798.087, 530406.509 4...
# 4    c005-h5000m  POLYGON ((534736.636 4701798.087, 539066.763 4...
# ..           ...                                                ...
# 175  c176-h5000m  POLYGON ((629999.43 4761798.087, 634329.557 47...
# 176  c177-h5000m  POLYGON ((638659.684 4761798.087, 642989.811 4...
# 177  c178-h5000m  POLYGON ((647319.938 4761798.087, 651650.065 4...
# 178  c179-h5000m  POLYGON ((655980.192 4761798.087, 660310.319 4...
# 179  c180-h5000m  POLYGON ((664640.446 4761798.087, 668970.573 4...
#
#                            centroid
# 0     POINT (500095.62 4696798.087)
# 1    POINT (508755.874 4696798.087)
# 2    POINT (517416.128 4696798.087)
# 3    POINT (526076.382 4696798.087)
# 4    POINT (534736.636 4696798.087)
# ..                              ...
# 175   POINT (629999.43 4756798.087)
# 176  POINT (638659.684 4756798.087)
# 177  POINT (647319.938 4756798.087)
# 178  POINT (655980.192 4756798.087)
# 179  POINT (664640.446 4756798.087)
#
# [180 rows x 3 columns]

# %% [markdown]
# ##### Extent based on Sections

# %%
u_sections = Sections.from_file(filepath=import_folder+'sections.gpkg', crs_working='EPSG:32619')
u_cells = Cells.delimit(
    extent=u_sections,
    var='hexagonal',
    side=5000)
u_cells.cells
# Out:
# Success: file opened.
# Success: reprojected to CRS "EPSG:32619"
# Success: section IDs generated.
#          cell_id                                            polygon  \
# 0    c001-h5000m  POLYGON ((500095.62 4701798.087, 504425.747 46...
# 1    c002-h5000m  POLYGON ((508755.874 4701798.087, 513086.001 4...
# 2    c003-h5000m  POLYGON ((517416.128 4701798.087, 521746.255 4...
# 3    c004-h5000m  POLYGON ((526076.382 4701798.087, 530406.509 4...
# 4    c005-h5000m  POLYGON ((534736.636 4701798.087, 539066.763 4...
# ..           ...                                                ...
# 175  c176-h5000m  POLYGON ((629999.43 4761798.087, 634329.557 47...
# 176  c177-h5000m  POLYGON ((638659.684 4761798.087, 642989.811 4...
# 177  c178-h5000m  POLYGON ((647319.938 4761798.087, 651650.065 4...
# 178  c179-h5000m  POLYGON ((655980.192 4761798.087, 660310.319 4...
# 179  c180-h5000m  POLYGON ((664640.446 4761798.087, 668970.573 4...
#
#                            centroid
# 0     POINT (500095.62 4696798.087)
# 1    POINT (508755.874 4696798.087)
# 2    POINT (517416.128 4696798.087)
# 3    POINT (526076.382 4696798.087)
# 4    POINT (534736.636 4696798.087)
# ..                              ...
# 175   POINT (629999.43 4756798.087)
# 176  POINT (638659.684 4756798.087)
# 177  POINT (647319.938 4756798.087)
# 178  POINT (655980.192 4756798.087)
# 179  POINT (664640.446 4756798.087)
#
# [180 rows x 3 columns]

# %% [markdown]
# #### Cells attributes

# %%
u_cells.name
# Out:
# 'cells-h5000m'

# %%
u_cells.parameters
# Out:
# {'cells_crs': 'EPSG:32619',
#  'cells_extent': '495765.49253164633, 4691798.086839909, 673300.7003074563, 4761798.086839909',
#  'cells_extent_source': 'Sections - sections-sections',
#  'cells_var': 'hexagonal',
#  'cells_side': 5000,
#  'cells_unit': 'metre',
#  'cells_buffer': None}

# %%
u_cells.cells
# Out:
#          cell_id                                            polygon  \
# 0    c001-h5000m  POLYGON ((500095.62 4701798.087, 504425.747 46...
# 1    c002-h5000m  POLYGON ((508755.874 4701798.087, 513086.001 4...
# 2    c003-h5000m  POLYGON ((517416.128 4701798.087, 521746.255 4...
# 3    c004-h5000m  POLYGON ((526076.382 4701798.087, 530406.509 4...
# 4    c005-h5000m  POLYGON ((534736.636 4701798.087, 539066.763 4...
# ..           ...                                                ...
# 175  c176-h5000m  POLYGON ((629999.43 4761798.087, 634329.557 47...
# 176  c177-h5000m  POLYGON ((638659.684 4761798.087, 642989.811 4...
# 177  c178-h5000m  POLYGON ((647319.938 4761798.087, 651650.065 4...
# 178  c179-h5000m  POLYGON ((655980.192 4761798.087, 660310.319 4...
# 179  c180-h5000m  POLYGON ((664640.446 4761798.087, 668970.573 4...
#
#                            centroid
# 0     POINT (500095.62 4696798.087)
# 1    POINT (508755.874 4696798.087)
# 2    POINT (517416.128 4696798.087)
# 3    POINT (526076.382 4696798.087)
# 4    POINT (534736.636 4696798.087)
# ..                              ...
# 175   POINT (629999.43 4756798.087)
# 176  POINT (638659.684 4756798.087)
# 177  POINT (647319.938 4756798.087)
# 178  POINT (655980.192 4756798.087)
# 179  POINT (664640.446 4756798.087)
#
# [180 rows x 3 columns]

# %% [markdown]
# #### ```Cells.save```

# %%
u_cells.save(
    folder=export_folder, 
    crs_export='EPSG:4326')
# Out:
# Success: additional geometry column "centroid" reprojected to CRS "EPSG:4326"
# Success: reprojected to CRS "EPSG:4326"

# %% [markdown]
# #### ```Cells.open```

# %%
u_cells = Cells.open(
    export_folder, 
    basename='cells-h5000m', 
    crs_working='EPSG:32619')
# Out:
# Success: file opened.
# Success: file opened.
# Success: file opened.
# Success: additional geometry column "centroid" reprojected to CRS "EPSG:32619"
# Success: reprojected to CRS "EPSG:32619"

# %% [markdown]
# #### ```Cells.plot```

# %%
u_sightings = DataPoints.from_file(filepath=import_folder+'sightings.gpkg', crs_working='EPSG:32619')
u_sections = Sections.from_file(filepath=import_folder+'sections.gpkg', crs_working='EPSG:32619')
u_cells.plot(datapoints=u_sightings, sections=u_sections)
# Out:
# Success: file opened.
# Success: reprojected to CRS "EPSG:32619"
# Success: datapoint IDs generated.
# Success: file opened.
# Success: reprojected to CRS "EPSG:32619"
# Success: section IDs generated.

# %% [markdown]
# ### Segments

# %% [markdown]
# #### ```Segments.delimit```

# %% [markdown]
# ##### Simple variation - not randomised

# %%
u_sections = Sections.from_file(filepath=import_folder+'sections.gpkg', crs_working='EPSG:32619')
u_segments = Segments.delimit(
    sections=u_sections,
    var='simple',
    target=10000)
u_segments.segments
# Out:
# Success: file opened.
# Success: reprojected to CRS "EPSG:32619"
# Success: section IDs generated.
#      segment_id                                               line  \
# 0   s01-s10000m  LINESTRING (580092.757 4742883.408, 579997.135...
# 1   s02-s10000m  LINESTRING (570094.222 4742829.916, 569917.081...
# 2   s03-s10000m  LINESTRING (560095.148 4742773.163, 559864.339...
# 3   s04-s10000m  LINESTRING (550095.667 4742710.935, 549838.842...
# 4   s05-s10000m  LINESTRING (540095.882 4742645.456, 539704.822...
# ..          ...                                                ...
# 68  s69-s10000m  LINESTRING (646445.51 4697592.665, 646369.277 ...
# 69  s70-s10000m  LINESTRING (636447.691 4697428.025, 636124.889...
# 70  s71-s10000m  LINESTRING (626450.303 4697221.055, 626265.927...
# 71  s72-s10000m  LINESTRING (616451.814 4697047.259, 616228.106...
# 72  s73-s10000m  LINESTRING (606453.822 4696868.905, 606176.634...
#
#                           midpoint  date section_id  dfbsec_beg     dfbsec_end
# 0   POINT (575093.311 4742845.962)  None         s1         0.0   10000.000000
# 1    POINT (565094.73 4742799.725)  None         s1     10000.0   20000.000000
# 2   POINT (555095.521 4742749.119)  None         s1     20000.0   30000.000000
# 3   POINT (545095.787 4742676.383)  None         s1     30000.0   40000.000000
# 4   POINT (535096.832 4742648.569)  None         s1     40000.0   50000.000000
# ..                             ...   ...        ...         ...            ...
# 68   POINT (641446.66 4697508.557)  None         s4    280000.0  290000.000000
# 69  POINT (631448.609 4697332.185)  None         s4    290000.0  300000.000000
# 70   POINT (621451.09 4697132.369)  None         s4    300000.0  310000.000000
# 71  POINT (611453.214 4696946.859)  None         s4    310000.0  320000.000000
# 72  POINT (604402.045 4696820.177)  None         s4    320000.0  324105.324868
#
# [73 rows x 7 columns]

# %% [markdown]
# ##### Simple variation - randomised

# %%
u_sections = Sections.from_file(filepath=import_folder+'sections.gpkg', crs_working='EPSG:32619')
u_segments = Segments.delimit(
    sections=u_sections,
    var='simple',
    target=10000,
    rand=True)
u_segments.segments
# Out:
# Success: file opened.
# Success: reprojected to CRS "EPSG:32619"
# Success: section IDs generated.
#      segment_id                                               line  \
# 0   s01-s10000m  LINESTRING (580092.757 4742883.408, 579997.135...
# 1   s02-s10000m  LINESTRING (570094.222 4742829.916, 569917.081...
# 2   s03-s10000m  LINESTRING (560095.148 4742773.163, 559864.339...
# 3   s04-s10000m  LINESTRING (550095.667 4742710.935, 549838.842...
# 4   s05-s10000m  LINESTRING (540095.882 4742645.456, 539704.822...
# ..          ...                                                ...
# 68  s69-s10000m  LINESTRING (652338.76 4697682.02, 652197.878 4...
# 69  s70-s10000m  LINESTRING (642341.15 4697526.723, 641994.147 ...
# 70  s71-s10000m  LINESTRING (632343.125 4697349.07, 632326.134 ...
# 71  s72-s10000m  LINESTRING (622345.629 4697147.973, 622000.67 ...
# 72  s73-s10000m  LINESTRING (612347.04 4696980.054, 612333.116 ...
#
#                           midpoint  date section_id     dfbsec_beg  \
# 0   POINT (575093.311 4742845.962)  None         s1       0.000000
# 1    POINT (565094.73 4742799.725)  None         s1   10000.000000
# 2   POINT (555095.521 4742749.119)  None         s1   20000.000000
# 3   POINT (545095.787 4742676.383)  None         s1   30000.000000
# 4   POINT (535096.832 4742648.569)  None         s1   40000.000000
# ..                             ...   ...        ...            ...
# 68  POINT (647339.987 4697611.472)  None         s4  274105.324868
# 69  POINT (637342.194 4697445.552)  None         s4  284105.324868
# 70  POINT (627344.065 4697254.461)  None         s4  294105.324868
# 71  POINT (617346.364 4697062.225)  None         s4  304105.324868
# 72  POINT (607348.392 4696882.591)  None         s4  314105.324868
#
#        dfbsec_end
# 0    10000.000000
# 1    20000.000000
# 2    30000.000000
# 3    40000.000000
# 4    50000.000000
# ..            ...
# 68  284105.324868
# 69  294105.324868
# 70  304105.324868
# 71  314105.324868
# 72  324105.324868
#
# [73 rows x 7 columns]

# %% [markdown]
# ##### Joining variation

# %%
u_sections = Sections.from_file(filepath=import_folder+'sections.gpkg', crs_working='EPSG:32619')
u_segments = Segments.delimit(
    sections=u_sections,
    var='joining',
    target=10000,
    rand=True)
u_segments.segments
# Out:
# Success: file opened.
# Success: reprojected to CRS "EPSG:32619"
# Success: section IDs generated.
#      segment_id                                               line  \
# 0   s01-j10000m  LINESTRING (580092.757 4742883.408, 579997.135...
# 1   s02-j10000m  LINESTRING (570094.222 4742829.916, 569917.081...
# 2   s03-j10000m  LINESTRING (560095.148 4742773.163, 559864.339...
# 3   s04-j10000m  LINESTRING (550095.667 4742710.935, 549838.842...
# 4   s05-j10000m  LINESTRING (540095.882 4742645.456, 539704.822...
# ..          ...                                                ...
# 64  s65-j10000m  LINESTRING (652338.76 4697682.02, 652197.878 4...
# 65  s66-j10000m  LINESTRING (642341.15 4697526.723, 641994.147 ...
# 66  s67-j10000m  LINESTRING (632343.125 4697349.07, 632326.134 ...
# 67  s68-j10000m  LINESTRING (622345.629 4697147.973, 622000.67 ...
# 68  s69-j10000m  LINESTRING (612347.04 4696980.054, 612333.116 ...
#
#                           midpoint  date section_id     dfbsec_beg  \
# 0   POINT (575093.311 4742845.962)  None         s1       0.000000
# 1    POINT (565094.73 4742799.725)  None         s1   10000.000000
# 2   POINT (555095.521 4742749.119)  None         s1   20000.000000
# 3   POINT (545095.787 4742676.383)  None         s1   30000.000000
# 4   POINT (535094.514 4742648.446)  None         s1   40000.000000
# ..                             ...   ...        ...            ...
# 64  POINT (647339.987 4697611.472)  None         s4  274105.324868
# 65  POINT (637342.194 4697445.552)  None         s4  284105.324868
# 66  POINT (627344.065 4697254.461)  None         s4  294105.324868
# 67  POINT (617346.364 4697062.225)  None         s4  304105.324868
# 68  POINT (607348.392 4696882.591)  None         s4  314105.324868
#
#        dfbsec_end
# 0    10000.000000
# 1    20000.000000
# 2    30000.000000
# 3    40000.000000
# 4    50004.642260
# ..            ...
# 64  284105.324868
# 65  294105.324868
# 66  304105.324868
# 67  314105.324868
# 68  324105.324868
#
# [69 rows x 7 columns]

# %% [markdown]
# ##### Redistribution variation

# %%
u_sections = Sections.from_file(filepath=import_folder+'sections.gpkg', crs_working='EPSG:32619')
u_segments = Segments.delimit(
    sections=u_sections,
    var='redistribution',
    target=10000)
u_segments.segments
# Out:
# Success: file opened.
# Success: reprojected to CRS "EPSG:32619"
# Success: section IDs generated.
#      segment_id                                               line  \
# 0   s01-r10000m  LINESTRING (580092.757 4742883.408, 579997.135...
# 1   s02-r10000m  LINESTRING (570093.642 4742829.91, 569917.081 ...
# 2   s03-r10000m  LINESTRING (560093.988 4742773.153, 559864.339...
# 3   s04-r10000m  LINESTRING (550093.926 4742710.923, 549838.842...
# 4   s05-r10000m  LINESTRING (540093.561 4742645.442, 539704.822...
# ..          ...                                                ...
# 64  s65-r10000m  LINESTRING (652980.044 4697677.144, 652979.945...
# 65  s66-r10000m  LINESTRING (642854.209 4697537.196, 642721.486...
# 66  s67-r10000m  LINESTRING (632727.93 4697356.37, 632683.219 4...
# 67  s68-r10000m  LINESTRING (622602.172 4697152.471, 622357.753...
# 68  s69-r10000m  LINESTRING (612475.314 4696982.119, 612333.116...
#
#                           midpoint  date section_id     dfbsec_beg  \
# 0   POINT (575093.021 4742845.959)  None         s1       0.000000
# 1    POINT (565093.86 4742799.716)  None         s1   10000.580283
# 2   POINT (555094.071 4742749.107)  None         s1   20001.160565
# 3   POINT (545093.756 4742676.369)  None         s1   30001.740848
# 4   POINT (535094.224 4742648.431)  None         s1   40002.321130
# ..                             ...   ...        ...            ...
# 64   POINT (647917.17 4697623.667)  None         s4  273463.867857
# 65  POINT (637791.127 4697454.392)  None         s4  283592.159259
# 66   POINT (627664.663 4697262.02)  None         s4  293720.450662
# 67   POINT (617538.774 4697065.46)  None         s4  303848.742064
# 68   POINT (607412.53 4696883.577)  None         s4  313977.033466
#
#        dfbsec_end
# 0    10000.580283
# 1    20001.160565
# 2    30001.740848
# 3    40002.321130
# 4    50002.901413
# ..            ...
# 64  283592.159259
# 65  293720.450662
# 66  303848.742064
# 67  313977.033466
# 68  324105.324868
#
# [69 rows x 7 columns]

# %% [markdown]
# #### ```Segments.datetimes```

# %%
u_trackpoints = DataPoints.from_file(
    filepath=import_folder+'trackpoints.csv',
    x_col='lon',
    y_col='lat',
    crs_import='EPSG:4326',
    crs_working='EPSG:32619',
    datetime_col='datetime',
    tz_import='UTC-05:00',
    section_id_col='section_id'
)
u_sections = Sections.from_datapoints(datapoints=u_trackpoints)
u_segments = Segments.delimit(
    sections=u_sections,
    var='redistribution',
    target=10000)
u_segments.datetimes(datapoints=u_trackpoints)
u_segments.segments
# Out:
# Success: file opened.
# Success: X and Y coordinates parsed.
# Success: reprojected to CRS "EPSG:32619"
# Success: column "datetime" reformatted to datetimes.
# Success: timezone of column "datetime" set to "UTC-05:00".
# Success: datapoint IDs generated.
#      segment_id                                               line  \
# 0   s01-r10000m  LINESTRING (580092.757 4742883.408, 579997.135...
# 1   s02-r10000m  LINESTRING (570093.642 4742829.91, 569917.081 ...
# 2   s03-r10000m  LINESTRING (560093.988 4742773.153, 559864.339...
# 3   s04-r10000m  LINESTRING (550093.926 4742710.923, 549838.842...
# 4   s05-r10000m  LINESTRING (540093.561 4742645.442, 539704.822...
# ..          ...                                                ...
# 64  s65-r10000m  LINESTRING (652980.044 4697677.144, 652979.945...
# 65  s66-r10000m  LINESTRING (642854.209 4697537.196, 642721.486...
# 66  s67-r10000m  LINESTRING (632727.93 4697356.37, 632683.219 4...
# 67  s68-r10000m  LINESTRING (622602.172 4697152.471, 622357.753...
# 68  s69-r10000m  LINESTRING (612475.314 4696982.119, 612333.116...
#
#                           midpoint        date              datetime_beg  \
# 0   POINT (575093.021 4742845.959)  2019-01-25 2019-01-25 10:18:13-05:00
# 1    POINT (565093.86 4742799.716)  2019-01-25 2019-01-25 10:21:38-05:00
# 2   POINT (555094.071 4742749.107)  2019-01-25 2019-01-25 10:24:57-05:00
# 3   POINT (545093.756 4742676.369)  2019-01-25 2019-01-25 10:28:17-05:00
# 4   POINT (535094.224 4742648.431)  2019-01-25 2019-01-25 10:31:35-05:00
# ..                             ...         ...                       ...
# 64   POINT (647917.17 4697623.667)  2019-03-05 2019-03-05 12:51:07-05:00
# 65  POINT (637791.127 4697454.392)  2019-03-05 2019-03-05 12:54:50-05:00
# 66   POINT (627664.663 4697262.02)  2019-03-05 2019-03-05 12:58:29-05:00
# 67   POINT (617538.774 4697065.46)  2019-03-05 2019-03-05 13:02:14-05:00
# 68   POINT (607412.53 4696883.577)  2019-03-05 2019-03-05 13:06:00-05:00
#
#                 datetime_mid              datetime_end section_id  \
# 0  2019-01-25 10:19:55-05:00 2019-01-25 10:21:38-05:00       s001
# 1  2019-01-25 10:23:17-05:00 2019-01-25 10:24:57-05:00       s001
# 2  2019-01-25 10:26:37-05:00 2019-01-25 10:28:17-05:00       s001
# 3  2019-01-25 10:29:56-05:00 2019-01-25 10:31:35-05:00       s001
# 4  2019-01-25 10:33:14-05:00 2019-01-25 10:34:53-05:00       s001
# ..                       ...                       ...        ...
# 64 2019-03-05 12:52:58-05:00 2019-03-05 12:54:50-05:00       s004
# 65 2019-03-05 12:56:39-05:00 2019-03-05 12:58:29-05:00       s004
# 66 2019-03-05 13:00:21-05:00 2019-03-05 13:02:14-05:00       s004
# 67 2019-03-05 13:04:07-05:00 2019-03-05 13:06:00-05:00       s004
# 68 2019-03-05 13:07:53-05:00 2019-03-05 13:09:46-05:00       s004
#
#        dfbsec_beg     dfbsec_end
# 0        0.000000   10000.580283
# 1    10000.580283   20001.160565
# 2    20001.160565   30001.740848
# 3    30001.740848   40002.321130
# 4    40002.321130   50002.901413
# ..            ...            ...
# 64  273463.867857  283592.159259
# 65  283592.159259  293720.450662
# 66  293720.450662  303848.742064
# 67  303848.742064  313977.033466
# 68  313977.033466  324105.324868
#
# [69 rows x 10 columns]

# %% [markdown]
# #### Segments attributes

# %%
u_segments.name
# Out:
# 'segments-r10000m'

# %%
u_segments.parameters
# Out:
# {'sections_name': 'sections-trackpoints',
#  'segments_crs': 'EPSG:32619',
#  'segments_var': 'redistribution',
#  'segments_rand': False,
#  'segments_target': 10000,
#  'segments_unit': 'metre'}

# %%
u_segments.segments
# Out:
#      segment_id                                               line  \
# 0   s01-r10000m  LINESTRING (580092.757 4742883.408, 579997.135...
# 1   s02-r10000m  LINESTRING (570093.642 4742829.91, 569917.081 ...
# 2   s03-r10000m  LINESTRING (560093.988 4742773.153, 559864.339...
# 3   s04-r10000m  LINESTRING (550093.926 4742710.923, 549838.842...
# 4   s05-r10000m  LINESTRING (540093.561 4742645.442, 539704.822...
# ..          ...                                                ...
# 64  s65-r10000m  LINESTRING (652980.044 4697677.144, 652979.945...
# 65  s66-r10000m  LINESTRING (642854.209 4697537.196, 642721.486...
# 66  s67-r10000m  LINESTRING (632727.93 4697356.37, 632683.219 4...
# 67  s68-r10000m  LINESTRING (622602.172 4697152.471, 622357.753...
# 68  s69-r10000m  LINESTRING (612475.314 4696982.119, 612333.116...
#
#                           midpoint        date              datetime_beg  \
# 0   POINT (575093.021 4742845.959)  2019-01-25 2019-01-25 10:18:13-05:00
# 1    POINT (565093.86 4742799.716)  2019-01-25 2019-01-25 10:21:38-05:00
# 2   POINT (555094.071 4742749.107)  2019-01-25 2019-01-25 10:24:57-05:00
# 3   POINT (545093.756 4742676.369)  2019-01-25 2019-01-25 10:28:17-05:00
# 4   POINT (535094.224 4742648.431)  2019-01-25 2019-01-25 10:31:35-05:00
# ..                             ...         ...                       ...
# 64   POINT (647917.17 4697623.667)  2019-03-05 2019-03-05 12:51:07-05:00
# 65  POINT (637791.127 4697454.392)  2019-03-05 2019-03-05 12:54:50-05:00
# 66   POINT (627664.663 4697262.02)  2019-03-05 2019-03-05 12:58:29-05:00
# 67   POINT (617538.774 4697065.46)  2019-03-05 2019-03-05 13:02:14-05:00
# 68   POINT (607412.53 4696883.577)  2019-03-05 2019-03-05 13:06:00-05:00
#
#                 datetime_mid              datetime_end section_id  \
# 0  2019-01-25 10:19:55-05:00 2019-01-25 10:21:38-05:00       s001
# 1  2019-01-25 10:23:17-05:00 2019-01-25 10:24:57-05:00       s001
# 2  2019-01-25 10:26:37-05:00 2019-01-25 10:28:17-05:00       s001
# 3  2019-01-25 10:29:56-05:00 2019-01-25 10:31:35-05:00       s001
# 4  2019-01-25 10:33:14-05:00 2019-01-25 10:34:53-05:00       s001
# ..                       ...                       ...        ...
# 64 2019-03-05 12:52:58-05:00 2019-03-05 12:54:50-05:00       s004
# 65 2019-03-05 12:56:39-05:00 2019-03-05 12:58:29-05:00       s004
# 66 2019-03-05 13:00:21-05:00 2019-03-05 13:02:14-05:00       s004
# 67 2019-03-05 13:04:07-05:00 2019-03-05 13:06:00-05:00       s004
# 68 2019-03-05 13:07:53-05:00 2019-03-05 13:09:46-05:00       s004
#
#        dfbsec_beg     dfbsec_end
# 0        0.000000   10000.580283
# 1    10000.580283   20001.160565
# 2    20001.160565   30001.740848
# 3    30001.740848   40002.321130
# 4    40002.321130   50002.901413
# ..            ...            ...
# 64  273463.867857  283592.159259
# 65  283592.159259  293720.450662
# 66  293720.450662  303848.742064
# 67  303848.742064  313977.033466
# 68  313977.033466  324105.324868
#
# [69 rows x 10 columns]

# %% [markdown]
# #### ```Segments.save```

# %%
u_segments.save(
    folder=export_folder, 
    crs_export='EPSG:4326')
# Out:
# Success: additional geometry column "midpoint" reprojected to CRS "EPSG:4326"
# Success: reprojected to CRS "EPSG:4326"

# %% [markdown]
# #### ```Segments.open```

# %%
u_segments = Segments.open(
    export_folder, 
    basename='segments-r10000m', 
    crs_working='EPSG:32619')
# Out:
# Success: file opened.
# Success: file opened.
# Success: file opened.
# Success: additional geometry column "midpoint" reprojected to CRS "EPSG:32619"
# Success: reprojected to CRS "EPSG:32619"

# %% [markdown]
# #### ```Segments.plot```

# %%
u_sightings = DataPoints.from_file(filepath=import_folder+'sightings.gpkg', crs_working='EPSG:32619')
u_sections = Sections.from_file(filepath=import_folder+'sections.gpkg', crs_working='EPSG:32619')
u_segments.plot(datapoints=u_sightings, sections=u_sections)
# Out:
# Success: file opened.
# Success: reprojected to CRS "EPSG:32619"
# Success: datapoint IDs generated.
# Success: file opened.
# Success: reprojected to CRS "EPSG:32619"
# Success: section IDs generated.

# %% [markdown]
# ### Presences

# %% [markdown]
# #### ```Presences.delimit```

# %%
u_sightings = DataPoints.from_file(
    filepath=import_folder+'sightings.gpkg',
    crs_working='EPSG:32619',
    datetime_col='datetime',
    tz_import='UTC-05:00'
)
u_presences = Presences.delimit(
    datapoints=u_sightings,
    presence_col='individuals')
u_presences.presences
# Out:
# Success: file opened.
# Success: reprojected to CRS "EPSG:32619"
# Success: column "datetime" reformatted to datetimes.
# Success: timezone of column "datetime" set to "UTC-05:00".
# Success: datapoint IDs generated.
#    point_id                           point       date datapoint_id
# 0       p01   POINT (579166.78 4742872.701) 2019-01-25          d01
# 1       p02  POINT (554184.217 4742741.886) 2019-01-25          d02
# 2       p03  POINT (548599.876 4742700.214) 2019-01-25          d03
# 3       p04  POINT (520909.741 4714855.058) 2019-03-02          d04
# 4       p05  POINT (532548.249 4714899.835) 2019-03-02          d05
# 5       p06  POINT (512817.407 4705582.465) 2019-03-02          d06
# 6       p07   POINT (504710.41 4705553.392) 2019-03-02          d07
# 7       p08  POINT (654449.136 4716189.584) 2019-03-05          d08
# 8       p09  POINT (645666.237 4716110.937) 2019-03-05          d09
# 9       p10   POINT (643532.681 4716066.52) 2019-03-05          d10
# 10      p11  POINT (629124.489 4706545.106) 2019-03-05          d11
# 11      p12  POINT (620560.818 4697116.949) 2019-03-05          d12
# 12      p13  POINT (611976.857 4696974.111) 2019-03-05          d13

# %%
u_trackpoints = DataPoints.from_file(
    filepath=import_folder+'trackpoints.csv',
    x_col='lon',
    y_col='lat',
    crs_import='EPSG:4326',
    crs_working='EPSG:32619',
    datetime_col='datetime',
    tz_import='UTC-05:00',
    section_id_col='section_id'
)
u_presences = Presences.delimit(
    datapoints=u_sightings,
    presence_col='individuals',
    block='season')
u_presences.presences
# Out:
# Success: file opened.
# Success: X and Y coordinates parsed.
# Success: reprojected to CRS "EPSG:32619"
# Success: column "datetime" reformatted to datetimes.
# Success: timezone of column "datetime" set to "UTC-05:00".
# Success: datapoint IDs generated.
#    point_id                           point       date datapoint_id  season
# 0       p01   POINT (579166.78 4742872.701) 2019-01-25          d01  winter
# 1       p02  POINT (554184.217 4742741.886) 2019-01-25          d02  winter
# 2       p03  POINT (548599.876 4742700.214) 2019-01-25          d03  winter
# 3       p04  POINT (520909.741 4714855.058) 2019-03-02          d04  spring
# 4       p05  POINT (532548.249 4714899.835) 2019-03-02          d05  spring
# 5       p06  POINT (512817.407 4705582.465) 2019-03-02          d06  spring
# 6       p07   POINT (504710.41 4705553.392) 2019-03-02          d07  spring
# 7       p08  POINT (654449.136 4716189.584) 2019-03-05          d08  spring
# 8       p09  POINT (645666.237 4716110.937) 2019-03-05          d09  spring
# 9       p10   POINT (643532.681 4716066.52) 2019-03-05          d10  spring
# 10      p11  POINT (629124.489 4706545.106) 2019-03-05          d11  spring
# 11      p12  POINT (620560.818 4697116.949) 2019-03-05          d12  spring
# 12      p13  POINT (611976.857 4696974.111) 2019-03-05          d13  spring

# %% [markdown]
# #### Presences attributes

# %%
u_presences.name
# Out:
# 'presences-sightings'

# %%
u_presences.parameters
# Out:
# {'presences_crs': 'EPSG:32619'}

# %%
u_presences.presences
# Out:
#    point_id                           point       date datapoint_id  season
# 0       p01   POINT (579166.78 4742872.701) 2019-01-25          d01  winter
# 1       p02  POINT (554184.217 4742741.886) 2019-01-25          d02  winter
# 2       p03  POINT (548599.876 4742700.214) 2019-01-25          d03  winter
# 3       p04  POINT (520909.741 4714855.058) 2019-03-02          d04  spring
# 4       p05  POINT (532548.249 4714899.835) 2019-03-02          d05  spring
# 5       p06  POINT (512817.407 4705582.465) 2019-03-02          d06  spring
# 6       p07   POINT (504710.41 4705553.392) 2019-03-02          d07  spring
# 7       p08  POINT (654449.136 4716189.584) 2019-03-05          d08  spring
# 8       p09  POINT (645666.237 4716110.937) 2019-03-05          d09  spring
# 9       p10   POINT (643532.681 4716066.52) 2019-03-05          d10  spring
# 10      p11  POINT (629124.489 4706545.106) 2019-03-05          d11  spring
# 11      p12  POINT (620560.818 4697116.949) 2019-03-05          d12  spring
# 12      p13  POINT (611976.857 4696974.111) 2019-03-05          d13  spring

# %% [markdown]
# #### ```Presences.save```

# %%
u_presences.save(
    folder=export_folder, 
    crs_export='EPSG:4326')
# Out:
# Success: reprojected to CRS "EPSG:4326"

# %% [markdown]
# #### ```Presences.open```

# %%
u_presences = Presences.open(
    export_folder, 
    basename='presences-sightings', 
    crs_working='EPSG:32619')
# Out:
# Success: file opened.
# Success: file opened.
# Success: reprojected to CRS "EPSG:32619"

# %% [markdown]
# #### ```Presences.plot```

# %%
u_presences.plot()

# %% [markdown]
# ### PresenceZones

# %% [markdown]
# #### ```PresenceZones.delimit```

# %% [markdown]
# ##### Setup

# %%
u_sections = Sections.from_file(
    filepath=import_folder+'sections.gpkg',
    crs_working='EPSG:32619',
    datetime_col='datetime',
    tz_import='UTC-05:00',
    section_id_col='section_id'
)
u_sightings = DataPoints.from_file(
    filepath=import_folder+'sightings.gpkg',
    crs_working='EPSG:32619',
    datetime_col='datetime',
    tz_import='UTC-05:00'
)
u_presences = Presences.delimit(
    datapoints=u_sightings,
    presence_col='individuals')
# Out:
# Success: file opened.
# Success: reprojected to CRS "EPSG:32619"
# Success: column "datetime" reformatted to datetimes.
# Success: timezone of column "datetime" set to "UTC-05:00".
# Success: file opened.
# Success: reprojected to CRS "EPSG:32619"
# Success: column "datetime" reformatted to datetimes.
# Success: timezone of column "datetime" set to "UTC-05:00".
# Success: datapoint IDs generated.

# %% [markdown]
# ##### Without temporal threshold

# %%
u_presencezones = PresenceZones.delimit(
    sections=u_sections,
    presences=u_presences,
    sp_threshold=10000
)
u_presencezones.presencezones
# Out:
#   section_id                                      presencezones
# 0        all  MULTIPOLYGON (((506661.313 4695745.539, 505690...

# %% [markdown]
# ##### With temporal threshold

# %%
u_presencezones = PresenceZones.delimit(
    sections=u_sections,
    presences=u_presences,
    sp_threshold=10000,
    tm_threshold=0,
    tm_unit='day',
)
u_presencezones.presencezones
# Out:
#   section_id                                      presencezones
# 0       s001  MULTIPOLYGON (((550550.779 4732892.362, 549580...
# 1       s002                                               None
# 2       s003  POLYGON ((507613.256 4695983.989, 506661.313 4...
# 3       s004  POLYGON ((614879.704 4687404.708, 613927.76 46...

# %% [markdown]
# #### PresenceZones attributes

# %%
u_presencezones.name
# Out:
# 'presencezones-10000m-0day'

# %%
u_presencezones.parameters
# Out:
# {'presencezones_crs': 'EPSG:32619',
#  'presencezones_sp_threshold': 10000,
#  'presencezones_tm_threshold': 0,
#  'presencezones_tm_unit': 'day'}

# %%
u_presencezones.presencezones
# Out:
#   section_id                                      presencezones
# 0       s001  MULTIPOLYGON (((550550.779 4732892.362, 549580...
# 1       s002                                               None
# 2       s003  POLYGON ((507613.256 4695983.989, 506661.313 4...
# 3       s004  POLYGON ((614879.704 4687404.708, 613927.76 46...

# %% [markdown]
# #### ```PresenceZones.save```

# %%
u_presencezones.save(
    folder=export_folder, 
    crs_export='EPSG:4326')
# Out:
# Success: reprojected to CRS "EPSG:4326"

# %% [markdown]
# #### ```PresenceZones.open```

# %%
u_presencezones = PresenceZones.open(
    export_folder, 
    basename='presencezones-10000m-0doy', 
    crs_working='EPSG:32619')
# Out:
# Success: file opened.
# Success: file opened.
# Success: reprojected to CRS "EPSG:32619"

# %% [markdown]
# #### ```PresenceZones.plot```

# %%
u_sections = Sections.from_file(filepath=import_folder+'sections.gpkg', crs_working='EPSG:32619')
u_presencezones.plot(sections=u_sections, presences=u_presences)
# Out:
# Success: file opened.
# Success: reprojected to CRS "EPSG:32619"
# Success: section IDs generated.

# %% [markdown]
# ### Absences

# %% [markdown]
# #### ```Absences.delimit```

# %% [markdown]
# ##### Setup

# %%
u_trackpoints = DataPoints.from_file(
    filepath=import_folder+'trackpoints.csv',
    x_col='lon',
    y_col='lat',
    crs_import='EPSG:4326',
    crs_working='EPSG:32619',
    datetime_col='datetime',
    tz_import='UTC-05:00',
    section_id_col='section_id'
)
u_sections = Sections.from_datapoints(
    datapoints=u_trackpoints,
    cols={'season': 'first'})
u_sightings = DataPoints.from_file(
    filepath=import_folder+'sightings.gpkg',
    crs_working='EPSG:32619',
    datetime_col='datetime',
    tz_import='UTC-05:00'
)
u_presences = Presences.delimit(
    datapoints=u_sightings,
    presence_col='individuals',
    block='season')
u_presencezones = PresenceZones.delimit(
    sections=u_sections,
    presences=u_presences,
    sp_threshold=10000,
    tm_threshold=0,
    tm_unit='day'
)
# Out:
# Success: file opened.
# Success: X and Y coordinates parsed.
# Success: reprojected to CRS "EPSG:32619"
# Success: column "datetime" reformatted to datetimes.
# Success: timezone of column "datetime" set to "UTC-05:00".
# Success: datapoint IDs generated.
# Success: file opened.
# Success: reprojected to CRS "EPSG:32619"
# Success: column "datetime" reformatted to datetimes.
# Success: timezone of column "datetime" set to "UTC-05:00".
# Success: datapoint IDs generated.

# %% [markdown]
# ##### Along-the-line variation

# %% [markdown]
# ###### Without blocks

# %%
u_absences = Absences.delimit(
    sections=u_sections,
    presencezones=u_presencezones,
    var='along',
    target=20,
    limit=2)
u_absences.absences
# Out:
# Target: 20 | Attempts: 36 | Successes: 20
#    point_id                           point       date section_id  \
# 0       a01  POINT (590790.598 4733700.577) 2019-01-30       s002
# 1       a02    POINT (557794.996 4733536.1) 2019-01-30       s002
# 2       a03  POINT (512673.294 4733287.045) 2019-01-30       s002
# 3       a04  POINT (555599.622 4715028.308) 2019-03-02       s003
# 4       a05  POINT (580823.742 4715164.303) 2019-03-02       s003
# 5       a06  POINT (584424.755 4715169.989) 2019-03-02       s003
# 6       a07  POINT (579075.944 4705945.002) 2019-03-02       s003
# 7       a08  POINT (541395.996 4705749.169) 2019-03-02       s003
# 8       a09  POINT (656814.433 4737365.277) 2019-03-05       s004
# 9       a10  POINT (655690.591 4734763.507) 2019-03-05       s004
# 10      a11  POINT (627840.339 4734278.323) 2019-03-05       s004
# 11      a12  POINT (614424.918 4734037.788) 2019-03-05       s004
# 12      a13   POINT (602738.914 4724752.77) 2019-03-05       s004
# 13      a14   POINT (638654.09 4725243.396) 2019-03-05       s004
# 14      a15   POINT (620371.505 4715644.32) 2019-03-05       s004
# 15      a16  POINT (615564.758 4715544.919) 2019-03-05       s004
# 16      a17  POINT (604904.639 4715320.227) 2019-03-05       s004
# 17      a18  POINT (602746.463 4709985.292) 2019-03-05       s004
# 18      a19  POINT (657266.032 4706500.095) 2019-03-05       s004
# 19      a20   POINT (648786.633 4697642.13) 2019-03-05       s004
#
#              dfbs
# 0    82143.456152
# 1   115142.918826
# 2   160268.054178
# 3   227809.698648
# 4   253038.183571
# 5   256639.882382
# 6   296099.015506
# 7   333782.434721
# 8   388774.299640
# 9   392169.437606
# 10  420029.852687
# 11  433449.669795
# 12  454607.430177
# 13  490573.477967
# 14  554594.371474
# 15  559402.540567
# 16  570067.308302
# 17  577067.416602
# 18  635298.634908
# 19  652579.614878

# %% [markdown]
# ###### With blocks, ```how='target'```

# %%
u_absences = Absences.delimit(
    sections=u_sections,
    presencezones=u_presencezones,
    var='along',
    target=5,
    block='season',
    how='target')
u_absences.absences
# Out:
# Block: winter
# Target: 5 | Attempts: 8 | Successes: 5
#
# Block: spring
# Target: 5 | Attempts: 6 | Successes: 5
#   point_id                           point       date section_id  \
# 0      a01  POINT (565325.639 4742801.911) 2019-01-25       s001
# 1      a02   POINT (524748.032 4742610.96) 2019-01-25       s001
# 2      a03  POINT (580998.767 4733639.305) 2019-01-30       s002
# 3      a04   POINT (572551.956 4733600.94) 2019-01-30       s002
# 4      a05  POINT (556771.129 4733527.604) 2019-01-30       s002
# 5      a06  POINT (656647.361 4744711.786) 2019-03-05       s004
# 6      a07  POINT (629567.958 4725067.455) 2019-03-05       s004
# 7      a08   POINT (611551.92 4715479.321) 2019-03-05       s004
# 8      a09  POINT (602739.356 4710466.645) 2019-03-05       s004
# 9      a10  POINT (650567.175 4697662.501) 2019-03-05       s004
#
#             dfbs  season
# 0   14769.080347  winter
# 1   55350.445393  winter
# 2   91936.610473  winter
# 3  100384.479865  winter
# 4  116166.821611  winter
# 5  208838.048224  spring
# 6  308897.799273  spring
# 7  390828.072762  spring
# 8  403998.168852  spring
# 9  478210.817611  spring

# %% [markdown]
# ###### With blocks, ```how='average'```

# %%
u_absences = Absences.delimit(
    sections=u_sections,
    presencezones=u_presencezones,
    var='along',
    target=10,
    block='season',
    how='average')
u_absences.absences
# Out:
# Block: winter
# Target: 5 | Attempts: 5 | Successes: 5
#
# Block: spring
# Target: 5 | Attempts: 6 | Successes: 5
#   point_id                           point       date section_id  \
# 0      a01  POINT (583173.442 4733646.267) 2019-01-30       s002
# 1      a02  POINT (571291.713 4733587.817) 2019-01-30       s002
# 2      a03  POINT (568567.412 4733579.114) 2019-01-30       s002
# 3      a04  POINT (554950.865 4733512.883) 2019-01-30       s002
# 4      a05  POINT (541308.303 4733435.588) 2019-01-30       s002
# 5      a06  POINT (585388.766 4715164.004) 2019-03-02       s003
# 6      a07  POINT (653892.186 4734738.129) 2019-03-05       s004
# 7      a08  POINT (607764.261 4724655.679) 2019-03-05       s004
# 8      a09  POINT (609941.114 4715434.759) 2019-03-05       s004
# 9      a10  POINT (657680.968 4700352.766) 2019-03-05       s004
#
#             dfbs  season
# 0   89761.612803  winter
# 1  101644.790736  winter
# 2  104369.405601  winter
# 3  117987.145149  winter
# 4  131630.287804  winter
# 5   85016.302525  spring
# 6  221381.022449  spring
# 7  287089.437216  spring
# 8  392439.804842  spring
# 9  468894.243953  spring

# %% [markdown]
# ###### With blocks, ```how='effort'```

# %%
u_absences = Absences.delimit(
    sections=u_sections,
    presencezones=u_presencezones,
    var='along',
    target=100,
    block='season',
    how='effort')
lengths = u_sections.sections.copy()
lengths['length'] = lengths.length
lengths = lengths.groupby('season').agg({'length': 'sum'})
lengths['length_percentage'] = lengths['length'] / sum(lengths['length']) * 100
print('\n', lengths['length_percentage'], '\n')
u_absences.absences
# Out:
# Block: winter
# Target: 25 | Attempts: 34 | Successes: 25
#
# Block: spring
# Target: 76 | Attempts: 112 | Successes: 76
#
#  season
# spring    75.310261
# winter    24.689739
# Name: length_percentage, dtype: float64
#     point_id                           point       date section_id  \
# 0       a001  POINT (567624.969 4742805.227) 2019-01-25       s001
# 1       a002  POINT (567258.352 4742813.482) 2019-01-25       s001
# 2       a003   POINT (532894.358 4742626.17) 2019-01-25       s001
# 3       a004  POINT (529960.828 4742631.662) 2019-01-25       s001
# 4       a005   POINT (520251.34 4742596.267) 2019-01-25       s001
# ..       ...                             ...        ...        ...
# 96      a097  POINT (657656.562 4703835.438) 2019-03-05       s004
# 97      a098   POINT (653141.777 4697680.69) 2019-03-05       s004
# 98      a099  POINT (652846.381 4697680.347) 2019-03-05       s004
# 99      a100  POINT (651428.216 4697662.224) 2019-03-05       s004
# 100     a101  POINT (639104.885 4697477.181) 2019-03-05       s004
#
#               dfbs  season
# 0     12469.377161  winter
# 1     12836.178938  winter
# 2     47202.835040  winter
# 3     50136.744910  winter
# 4     59847.161621  winter
# ..             ...     ...
# 96   465411.095529  spring
# 97   475635.514742  spring
# 98   475930.988403  spring
# 99   477349.502607  spring
# 100  489675.699600  spring
#
# [101 rows x 6 columns]

# %% [markdown]
# ###### With blocks, ```how='presences'```

# %%
u_absences = Absences.delimit(
    sections=u_sections,
    presencezones=u_presencezones,
    var='along',
    target=2,
    block='season',
    how='presences',
    presences=u_presences)
print('\n', u_presences.presences['season'].value_counts(), '\n')
u_absences.absences
# Out:
# Block: winter
# Target: 6 | Attempts: 6 | Successes: 6
#
# Block: spring
# Target: 20 | Attempts: 36 | Successes: 20
#
#  season
# spring    10
# winter     3
# Name: count, dtype: int64
#    point_id                           point       date section_id  \
# 0       a01  POINT (592820.443 4733695.531) 2019-01-30       s002
# 1       a02   POINT (584411.42 4733661.285) 2019-01-30       s002
# 2       a03  POINT (573528.643 4733592.389) 2019-01-30       s002
# 3       a04  POINT (554623.385 4733510.286) 2019-01-30       s002
# 4       a05  POINT (542937.772 4733445.525) 2019-01-30       s002
# 5       a06  POINT (521475.863 4733345.449) 2019-01-30       s002
# 6       a07  POINT (563726.708 4715098.103) 2019-03-02       s003
# 7       a08  POINT (576898.685 4715157.015) 2019-03-02       s003
# 8       a09  POINT (583199.264 4715155.204) 2019-03-02       s003
# 9       a10  POINT (586398.384 4715176.484) 2019-03-02       s003
# 10      a11   POINT (595621.88 4715195.947) 2019-03-02       s003
# 11      a12   POINT (537483.77 4705727.025) 2019-03-02       s003
# 12      a13  POINT (656624.901 4745698.694) 2019-03-05       s004
# 13      a14  POINT (647577.632 4734648.902) 2019-03-05       s004
# 14      a15  POINT (644261.403 4734578.828) 2019-03-05       s004
# 15      a16  POINT (611312.416 4733971.713) 2019-03-05       s004
# 16      a17   POINT (602389.98 4729436.545) 2019-03-05       s004
# 17      a18  POINT (603172.853 4724575.069) 2019-03-05       s004
# 18      a19  POINT (603730.252 4724539.018) 2019-03-05       s004
# 19      a20  POINT (622592.706 4724940.481) 2019-03-05       s004
# 20      a21  POINT (614804.628 4715532.315) 2019-03-05       s004
# 21      a22  POINT (615617.154 4706288.969) 2019-03-05       s004
# 22      a23   POINT (656540.643 4697774.42) 2019-03-05       s004
# 23      a24  POINT (656181.085 4697730.691) 2019-03-05       s004
# 24      a25  POINT (644384.991 4697568.664) 2019-03-05       s004
# 25      a26  POINT (635426.855 4697408.163) 2019-03-05       s004
#
#              dfbs  season
# 0    80113.121905  winter
# 1    88523.544411  winter
# 2    99407.530185  winter
# 3   118314.634616  winter
# 4   130000.788848  winter
# 5   151463.758980  winter
# 6    63350.155159  spring
# 7    76524.606413  spring
# 8    82826.459281  spring
# 9    86025.997719  spring
# 10   95251.276417  spring
# 11  165106.880959  spring
# 12  207850.884400  spring
# 13  227698.919697  spring
# 14  231015.889168  spring
# 15  263975.356958  spring
# 16  277249.290721  spring
# 17  282493.496089  spring
# 18  283052.860990  spring
# 19  301921.391084  spring
# 20  387574.932986  spring
# 21  420806.586751  spring
# 22  472229.553169  spring
# 23  472591.761094  spring
# 24  484394.471780  spring
# 25  493354.447223  spring

# %% [markdown]
# ##### From-the-line variation

# %%
from sampley.functions import generate_dfls
from math import exp
def detection_func(x): return exp((-x**2) / (2*500**2))
number = 100000
esw = 2000
interval = 1
dfls = generate_dfls(number=number, esw=esw, interval=interval, dfunc=detection_func)
u_absences = Absences.delimit(
    sections=u_sections,
    presencezones=u_presencezones,
    var='from',
    target=20,
    dfls=dfls)
# Out:
# Target: 20 | Attempts: 28 | Successes: 20

# %% [markdown]
# ###### Additional test of distribution of distances from the line

# %%
import matplotlib.pyplot as plt
dfls_absences = Absences.delimit(
    sections=u_sections,
    presencezones=u_presencezones,
    var='from',
    target=10000,
    dfls=dfls).absences.distance(u_sections.sections.dissolve().geometry[0])
fig, ax = plt.subplots(figsize=(16, 6), ncols=2)
ax[0].hist(dfls, bins=50, facecolor='none', edgecolor='black');
ax[1].hist(dfls_absences, bins=50, facecolor='none', edgecolor='black');
# Out:
# Target: 10000 | Attempts: 15094 | Successes: 10000

# %% [markdown]
# #### Absences attributes

# %%
u_absences.name
# Out:
# 'absences-fs-10000m-0day'

# %%
u_absences.parameters
# Out:
# {'absences_var': 'from',
#  'absences_target': 20,
#  'presencezones_crs': 'EPSG:32619',
#  'presencezones_sp_threshold': 10000,
#  'presencezones_tm_threshold': 0,
#  'presencezones_tm_unit': 'day'}

# %%
u_absences.absences
# Out:
#    point_id                           point       date section_id  \
# 0       a01  POINT (529886.319 4743026.343) 2019-01-25       s001
# 1       a02  POINT (516330.454 4742597.856) 2019-01-25       s001
# 2       a03  POINT (521038.519 4733432.105) 2019-01-30       s002
# 3       a04  POINT (577594.206 4715627.776) 2019-03-02       s003
# 4       a05  POINT (542411.876 4706100.285) 2019-03-02       s003
# 5       a06  POINT (541669.381 4706122.804) 2019-03-02       s003
# 6       a07  POINT (655858.606 4745966.627) 2019-03-05       s004
# 7       a08  POINT (656143.481 4742282.714) 2019-03-05       s004
# 8       a09  POINT (657235.943 4739767.762) 2019-03-05       s004
# 9       a10  POINT (644051.283 4735854.721) 2019-03-05       s004
# 10      a11  POINT (615638.473 4734569.071) 2019-03-05       s004
# 11      a12  POINT (614981.156 4725208.119) 2019-03-05       s004
# 12      a13  POINT (622775.337 4724603.664) 2019-03-05       s004
# 13      a14  POINT (625679.435 4725419.873) 2019-03-05       s004
# 14      a15  POINT (632975.679 4725553.121) 2019-03-05       s004
# 15      a16  POINT (634398.377 4725603.586) 2019-03-05       s004
# 16      a17  POINT (610360.414 4716514.544) 2019-03-05       s004
# 17      a18    POINT (616101.65 4706240.02) 2019-03-05       s004
# 18      a19   POINT (655950.76 4698319.317) 2019-03-05       s004
# 19      a20  POINT (638495.664 4697912.408) 2019-03-05       s004
#
#              dfbs                                      point_al
# 0    50209.545212   POINT (529888.0285078413 4742631.346615674)
# 1    63768.033462   POINT (516330.48218331026 4742585.85570734)
# 2   151900.835636  POINT (521038.78870537423 4733344.104936959)
# 3   249813.194746  POINT (577599.3873754725 4715164.8048503315)
# 4   332764.442971   POINT (542413.9692646393 4705755.291433982)
# 5   333506.809232   POINT (541671.6165286088 4705750.810413116)
# 6   380153.426452    POINT (656618.409258712 4745983.920809806)
# 7   383842.876692   POINT (656702.3362294716 4742295.425271345)
# 8   386382.016092    POINT (656760.065625591 4739756.942218084)
# 9   403787.182885   POINT (644077.9917154282 4734574.999896842)
# 10  432227.403324    POINT (615647.015062572 4734058.142686687)
# 11  466902.761138    POINT (614988.0794229781 4724791.17652596)
# 12  474685.860505   POINT (622769.3051082569 4724943.610567544)
# 13  477604.141241   POINT (625687.1165561776 4724995.942971437)
# 14  484902.047950  POINT (632983.7508475563 4725132.1979103545)
# 15  486325.538078   POINT (634406.9758624755 4725159.669612275)
# 16  564591.223994   POINT (610377.4828049119 4715441.679285046)
# 17  593878.041594   POINT (616100.6990018071 4706297.011745469)
# 18  645398.897513   POINT (655964.4409085985 4697706.469254705)
# 19  662864.090173   POINT (638504.4632054863 4697468.495468175)

# %% [markdown]
# #### ```Absences.save```

# %%
u_absences.save(
    folder=export_folder, 
    crs_export='EPSG:4326')
# Out:
# Success: reprojected to CRS "EPSG:4326"

# %% [markdown]
# #### ```Absences.open```

# %%
u_absences = Absences.open(
    export_folder, 
    basename='absences-fs-10000m-0day', 
    crs_working='EPSG:32619')
# Out:
# Success: file opened.
# Success: file opened.
# Success: reprojected to CRS "EPSG:32619"

# %% [markdown]
# #### ```Absences.plot```

# %%
u_absences.plot()
